# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from scipy.stats import norm


data = pd.read_excel('C:/Users/Manav/Downloads/data.xlsx' )
print(data.describe())
plt.hist(data[['gold','oil','JPM']])

col1=data['Close_ETF']
col2=data['gold']

data.tail()
# Out:
#          Close_ETF          oil         gold          JPM
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean    121.152960     0.001030     0.000663     0.000530
# std      12.569790     0.021093     0.011289     0.011017
# min      96.419998    -0.116533    -0.065805    -0.048217
# 25%     112.580002    -0.012461    -0.004816    -0.005538
# 50%     120.150002     0.001243     0.001030     0.000386
# 75%     128.687497     0.014278     0.007482     0.006966
# max     152.619995     0.087726     0.042199     0.057480
#       Close_ETF       oil      gold       JPM
# 995  150.570007  0.009752  0.004634  0.003859
# 996  151.600006 -0.009341 -0.015325  0.018259
# 997  151.300003  0.036120 -0.006195 -0.007928
# 998  152.619995  0.001542  0.005778 -0.000381
# 999  152.539993  0.020330  0.001965  0.000381

# %% [markdown]
# # Part-3

# %%
#fig1=plt.hist(data['Close_ETF'], edgecolor="black")
#def hist_plot()

sns.distplot(data['Close_ETF'], bins=10)
plt.xlabel('Sample')
plt.ylabel('ETF')
plt.title('ETF Histogram')
plt.grid(True)
#plt.ylim([0,0.05])
#plt.xlim([0,200])

plt.show()

# %%
sns.distplot(data['oil'], bins=10)
plt.xlabel('Sample')
plt.ylabel('oil')
plt.title('oil Histogram')
plt.grid(True)

# %%
sns.distplot(data['gold'], bins=10)
plt.xlabel('Count')
plt.ylabel('Gold')
plt.title('Gold Histogram')
plt.grid(True)

# %%
sns.distplot(data['gold'], bins=10)
plt.xlabel('Count')
plt.ylabel('Gold')
plt.title('Gold Histogram')
plt.grid(True)

# %% [markdown]
# Hypotheses
#
# ETF
# Null Hypothesis- H0- The distribution of the data is normal
#
# Alternate Hypothesis- H1- The distribution of the data is not normal

# %% [markdown]
# OIL
#
# Null Hypothesis- H0- The distribution of the data is normal
#
# Alternate Hypothesis- H1- The distribution of the data is not normal
#
#
# Gold
#
# Null Hypothesis- H0- The distribution of the data is normal
#
# Alternate Hypothesis- H1- The distribution of the data is not normal
#
#
# JPM
#
# Null Hypothesis- H0- The distribution of the data is normal
#
# Alternate Hypothesis- H1- The distribution of the data is not normal

# %%
from scipy.stats import shapiro
from scipy.stats import anderson
from scipy.stats import kstest

# %%
#ShapiroWilk test
stat, p= shapiro(data['Close_ETF'])
print('Statistics=%.3f, p=%.3f' % (stat, p))

#interpretation
alpha=0.05

if p>alpha:
  print('Fail to reject H0')
else:
    print('Reject H0')
# Out:
# Statistics=0.980, p=0.000
# Reject H0

# %%
#AndersonDarling test

anderson(data['Close_ETF'], dist='norm')
# Out:
# AndersonResult(statistic=4.693163670316608, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
#SmirnovKolmogorov test

kstest(data['Close_ETF'],'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
import statsmodels.api as sm
import pylab as py

#QQplot
sm.qqplot(data['Close_ETF'], line ='45')
py.show()

# %% [markdown]
# Normality test for OIL

# %%
#Shapiro Wilk test
stat, p= shapiro(data['oil'])
oil_SWtest=print('Statistics=%.3f, p=%.3f' % (stat, p))
# Out:
# Statistics=0.989, p=0.000

# %%
#AndersonDarling test

anderson(data['oil'], dist='norm')
# Out:
# AndersonResult(statistic=1.1434806509929558, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
#SmirnovKolmogorov test

kstest(data['oil'],'norm')
# Out:
# KstestResult(statistic=0.4727185265212217, pvalue=1.2565304659417615e-205)

# %%
#QQplot
sm.qqplot(data['oil'], line ='45')
py.show()

# %% [markdown]
# Normality test for GOLD

# %%
#Shapiro Wilk test
stat, p= shapiro(data['gold'])
oil_SWtest=print('Statistics=%.3f, p=%.3f' % (stat, p))
# Out:
# Statistics=0.969, p=0.000

# %%
#AndersonDarling test

anderson(data['gold'], dist='norm')
# Out:
# AndersonResult(statistic=6.37729199194996, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
#SmirnovKolmogorov test

kstest(data['gold'],'norm')
# Out:
# KstestResult(statistic=0.48333847934283236, pvalue=1.4922487931964242e-215)

# %%
#QQplot
sm.qqplot(data['gold'], line ='45')
py.show()

# %% [markdown]
# Normality test for JPM

# %%
#Shapiro Wilk test
stat, p= shapiro(data['JPM'])
oil_SWtest=print('Statistics=%.3f, p=%.3f' % (stat, p))
# Out:
# Statistics=0.980, p=0.000

# %%
#AndersonDarling test

anderson(data['JPM'], dist='norm')
# Out:
# AndersonResult(statistic=3.883392153861564, critical_values=array([0.574, 0.653, 0.784, 0.914, 1.088]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]))

# %%
#SmirnovKolmogorov test

kstest(data['JPM'],'norm')
# Out:
# KstestResult(statistic=0.4829776270752645, pvalue=3.278870501508125e-215)

# %%
#QQplot
sm.qqplot(data['JPM'], line ='45')
py.show()

# %% [markdown]
# Part-4

# %%
#sample calling

d1=df[['Close_ETF',]]

i2=[]
j2=[]
n2=[]

for seq in range(0,1000,20):
    i2.append(seq)
    
        
for seq1 in range(20,1020,20):
    j2.append(seq1)
        

    
for k in range(0,50):
    nn=d1[i2[k]:j2[k]]
    
    n2.append(nn)
    
    
print(n2)
# Out:
# [     Close_ETF
# 0    97.349998
# 1    97.750000
# 2    99.160004
# 3    99.650002
# 4    99.260002
# 5    98.250000
# 6    99.250000
# 7   100.300003
# 8   100.610001
# 9    99.559998
# 10  101.660004
# 11  101.660004
# 12  101.570000
# 13  100.019997
# 14   99.440002
# 15   98.419998
# 16   98.519997
# 17   97.529999
# 18   98.800003
# 19   97.660004,      Close_ETF
# 20   97.629997
# 21   98.529999
# 22   99.769997
# 23   98.739998
# 24  100.699997
# 25  101.150002
# 26  100.580002
# 27   99.300003
# 28  100.239998
# 29  100.730003
# 30  100.510002
# 31   99.919998
# 32   98.500000
# 33   99.510002
# 34   98.279999
# 35   99.169998
# 36   99.239998
# 37   98.489998
# 38  100.230003
# 39   99.860001,      Close_ETF
# 40   99.400002
# 41   99.160004
# 42   99.389999
# 43   98.510002
# 44   98.510002
# 45   96.419998
# 46   96.980003
# 47   98.000000
# 48   98.279999
# 49   98.650002
# 50   99.550003
# 51   99.040001
# 52   99.309998
# 876  140.500000
# 877  140.639999
# 878  140.919998
# 879  140.350006,       Close_ETF
# 880  138.419998
# 881  139.020004
# 882  140.470001
# 883  140.529999
# 884  140.220001
# 885  141.289993
# 886  141.899994
# 887  141.779999
# 888  141.160004
# 889  141.419998
# 890  141.830002
# 891  141.720001
# 892  141.869995
# 893  143.119995
# 894  142.339996
# 895  141.949997
# 896  142.220001
# 897  142.139999
# 898  141.619995
# 899  140.750000,       Close_ETF
# 900  141.580002
# 901  142.509995
# 902  142.210007
# 903  141.619995
# 904  141.369995
# 905  141.669998
# 906  140.539993
# 907  141.190002
# 908  141.070007
# 909  141.539993
# 910  142.160004
# 911  143.240005
# 912  142.960007
# 913  143.020004
# 914  142.539993
# 915  142.820007
# 916  142.380005
# 917  142.800003
# 918  143.949997
# 919  142.259995,       Close_ETF
# 920  142.130005
# 921  142.050003
# 922  142.789993
# 923  143.750000
# 924  144.610001
# 925  144.809998
# 926  144.850006
# 927  144.889999
# 928  145.210007
# 929  145.020004
# 930  143.940002
# 931  143.449997
# 932  144.660004
# 933  145.610001
# 934  145.800003
# 935  145.729996
# 936  146.039993
# 937  145.979996
# 938  145.869995
# 939  145.300003,       Close_ETF
# 940  145.169998
# 941  139.500000
# 942  140.929993
# 943  140.509995
# 944  138.669998
# 945  137.350006
# 946  139.699997
# 947  139.559998
# 948  140.740005
# 949  140.779999
# 950  140.990005
# 951  138.250000
# 952  139.279999
# 953  139.470001
# 954  138.529999
# 955  140.199997
# 956  140.970001
# 957  143.289993
# 958  143.179993
# 959  143.389999,       Close_ETF
# 960  143.199997
# 961  142.860001
# 962  141.820007
# 963  141.970001
# 964  142.000000
# 965  142.160004
# 966  143.690002
# 967  143.850006
# 968  144.240005
# 969  144.440002
# 970  144.610001
# 971  144.020004
# 972  144.660004
# 973  145.320007
# 974  146.699997
# 975  147.089996
# 976  147.270004
# 977  147.229996
# 978  148.619995
# 979  148.059998,       Close_ETF
# 980  148.119995
# 981  149.479996
# 982  149.649994
# 983  149.529999
# 984  148.289993
# 985  148.669998
# 986  149.539993
# 987  150.350006
# 988  150.919998
# 989  150.949997
# 990  150.750000
# 991  151.160004
# 992  149.580002
# 993  150.860001
# 994  150.529999
# 995  150.570007
# 996  151.600006
# 997  151.300003
# 998  152.619995
# 999  152.539993]

# %%
#for calculating sample mean for 50 groups
mean=[]
for i in range(len(n2)):

    samplemean = np.mean(n2[i])
    mean.append(samplemean)
    
    print("#####################")
    
    print("Mean for sample number:",i+1)
    
    print(samplemean)
# Out:
# #####################
# Mean for sample number: 1
# Close_ETF    99.321001
# dtype: float64
# #####################
# Mean for sample number: 2
# Close_ETF    99.554
# dtype: float64
# #####################
# Mean for sample number: 3
# Close_ETF    99.154001
# dtype: float64
# #####################
# Mean for sample number: 4
# Close_ETF    102.5505
# dtype: float64
# #####################
# Mean for sample number: 5
# Close_ETF    103.292
# dtype: float64
# #####################
# Mean for sample number: 6
# Close_ETF    105.0935
# dtype: float64
# #####################
# Mean for sample number: 7
# Close_ETF    106.751
# dtype: float64
# #####################
# Mean for sample number: 8
# Close_ETF    111.658001
# dtype: float64
# #####################
# Mean for sample number: 9
# Close_ETF    114.4995
# dtype: float64
# #####################
# Mean for sample number: 10
# Close_ETF    114.4005
# dtype: float64
# #####################
# Mean for sample number: 11
# Close_ETF    112.7765
# dtype: float64
# #####################
# Mean for sample number: 12
# Close_ETF    112.286
# dtype: float64
# #####################
# Mean for sample number: 13
# Close_ETF    111.808999
# dtype: float64
# #####################
# Mean for sample number: 14
# Close_ETF    113.271499
# dtype: float64
# #####################
# Mean for sample number: 15
# Close_ETF    109.947499
# dtype: float64
# #####################
# Mean for sample number: 16
# Close_ETF    110.143
# dtype: float64
# #####################
# Mean for sample number: 17
# Close_ETF    112.5355
# dtype: float64
# #####################
# Mean for sample number: 18
# Close_ETF    112.0755
# dtype: float64
# #####################
# Mean for sample number: 19
# Close_ETF    117.781501
# dtype: float64
# #####################
# Mean for sample number: 20
# Close_ETF    120.0505
# dtype: float64
# #####################
# Mean for sample number: 21
# Close_ETF    118.208001
# dtype: float64
# #####################
# Mean for sample number: 22
# Close_ETF    119.980999
# dtype: float64
# #####################
# Mean for sample number: 23
# Close_ETF    119.7675
# dtype: float64
# #####################
# Mean for sample number: 24
# Close_ETF    116.803
# dtype: float64
# #####################
# Mean for sample number: 25
# Close_ETF    117.242
# dtype: float64
# #####################
# Mean for sample number: 26
# Close_ETF    120.554501
# dtype: float64
# #####################
# Mean for sample number: 27
# Close_ETF    121.0915
# dtype: float64
# #####################
# Mean for sample number: 28
# Close_ETF    123.41
# dtype: float64
# #####################
# Mean for sample number: 29
# Close_ETF    122.717
# dtype: float64
# #####################
# Mean for sample number: 30
# Close_ETF    120.611
# dtype: float64
# #####################
# Mean for sample number: 31
# Close_ETF    120.508
# dtype: float64
# #####################
# Mean for sample number: 32
# Close_ETF    125.797
# dtype: float64
# #####################
# Mean for sample number: 33
# Close_ETF    126.883
# dtype: float64
# #####################
# Mean for sample number: 34
# Close_ETF    127.3025
# dtype: float64
# #####################
# Mean for sample number: 35
# Close_ETF    128.4375
# dtype: float64
# #####################
# Mean for sample number: 36
# Close_ETF    130.136499
# dtype: float64
# #####################
# Mean for sample number: 37
# Close_ETF    130.5825
# dtype: float64
# #####################
# Mean for sample number: 38
# Close_ETF    128.159
# dtype: float64
# #####################
# Mean for sample number: 39
# Close_ETF    125.1255
# dtype: float64
# #####################
# Mean for sample number: 40
# Close_ETF    126.060001
# dtype: float64
# #####################
# Mean for sample number: 41
# Close_ETF    129.0295
# dtype: float64
# #####################
# Mean for sample number: 42
# Close_ETF    131.8115
# dtype: float64
# #####################
# Mean for sample number: 43
# Close_ETF    135.974
# dtype: float64
# #####################
# Mean for sample number: 44
# Close_ETF    138.857
# dtype: float64
# #####################
# Mean for sample number: 45
# Close_ETF    141.288499
# dtype: float64
# #####################
# Mean for sample number: 46
# Close_ETF    142.1715
# dtype: float64
# #####################
# Mean for sample number: 47
# Close_ETF    144.6245
# dtype: float64
# #####################
# Mean for sample number: 48
# Close_ETF    140.522999
# dtype: float64
# #####################
# Mean for sample number: 49
# Close_ETF    144.690501
# dtype: float64
# #####################
# Mean for sample number: 50
# Close_ETF    150.350499
# dtype: float64

# %%
#for calculating standard deviation for 50 groups
stand=[]
for i in range(len(n2)):

    std = np.std(n2[i])
    stand.append(std)
    
    print("#####################")
    
    print(" Standard deviation for sample number:",i+1)
    
    print(std)
# Out:
# #####################
#  Standard deviation for sample number: 1
# Close_ETF    1.313659
# dtype: float64
# #####################
#  Standard deviation for sample number: 2
# Close_ETF    0.948776
# dtype: float64
# #####################
#  Standard deviation for sample number: 3
# Close_ETF    1.136861
# dtype: float64
# #####################
#  Standard deviation for sample number: 4
# Close_ETF    1.166758
# dtype: float64
# #####################
#  Standard deviation for sample number: 5
# Close_ETF    1.852385
# dtype: float64
# #####################
#  Standard deviation for sample number: 6
# Close_ETF    0.96663
# dtype: float64
# #####################
#  Standard deviation for sample number: 7
# Close_ETF    1.289981
# dtype: float64
# #####################
#  Standard deviation for sample number: 8
# Close_ETF    1.614808
# dtype: float64
# #####################
#  Standard deviation for sample number: 9
# Close_ETF    0.953276
# dtype: float64
# #####################
#  Standard deviation for sample number: 10
# Close_ETF    1.590212
# dtype: float64
# #####################
#  Standard deviation for sample number: 11
# Close_ETF    1.824703
# dtype: float64
# #####################
#  Standard deviation for sample number: 12
# Close_ETF    1.602028
# dtype: float64
# #####################
#  Standard deviation for sample number: 13
# Close_ETF    1.877674
# dtype: float64
# #####################
#  Standard deviation for sample number: 14
# Close_ETF    0.969965
# dtype: float64
# #####################
#  Standard deviation for sample number: 15
# Close_ETF    1.346216
# dtype: float64
# #####################
#  Standard deviation for sample number: 16
# Close_ETF    1.647449
# dtype: float64
# #####################
#  Standard deviation for sample number: 17
# Close_ETF    0.965379
# dtype: float64
# #####################
#  Standard deviation for sample number: 18
# Close_ETF    1.321672
# dtype: float64
# #####################
#  Standard deviation for sample number: 19
# Close_ETF    0.954161
# dtype: float64
# #####################
#  Standard deviation for sample number: 20
# Close_ETF    0.908688
# dtype: float64
# #####################
#  Standard deviation for sample number: 21
# Close_ETF    1.095969
# dtype: float64
# #####################
#  Standard deviation for sample number: 22
# Close_ETF    0.882886
# dtype: float64
# #####################
#  Standard deviation for sample number: 23
# Close_ETF    2.011181
# dtype: float64
# #####################
#  Standard deviation for sample number: 24
# Close_ETF    1.606996
# dtype: float64
# #####################
#  Standard deviation for sample number: 25
# Close_ETF    1.44865
# dtype: float64
# #####################
#  Standard deviation for sample number: 26
# Close_ETF    0.645782
# dtype: float64
# #####################
#  Standard deviation for sample number: 27
# Close_ETF    1.522167
# dtype: float64
# #####################
#  Standard deviation for sample number: 28
# Close_ETF    0.714696
# dtype: float64
# #####################
#  Standard deviation for sample number: 29
# Close_ETF    1.076025
# dtype: float64
# #####################
#  Standard deviation for sample number: 30
# Close_ETF    1.777816
# dtype: float64
# #####################
#  Standard deviation for sample number: 31
# Close_ETF    1.83521
# dtype: float64
# #####################
#  Standard deviation for sample number: 32
# Close_ETF    1.150127
# dtype: float64
# #####################
#  Standard deviation for sample number: 33
# Close_ETF    1.285803
# dtype: float64
# #####################
#  Standard deviation for sample number: 34
# Close_ETF    1.009151
# dtype: float64
# #####################
#  Standard deviation for sample number: 35
# Close_ETF    0.865153
# dtype: float64
# #####################
#  Standard deviation for sample number: 36
# Close_ETF    0.576283
# dtype: float64
# #####################
#  Standard deviation for sample number: 37
# Close_ETF    1.113776
# dtype: float64
# #####################
#  Standard deviation for sample number: 38
# Close_ETF    2.046089
# dtype: float64
# #####################
#  Standard deviation for sample number: 39
# Close_ETF    1.390832
# dtype: float64
# #####################
#  Standard deviation for sample number: 40
# Close_ETF    1.531856
# dtype: float64
# #####################
#  Standard deviation for sample number: 41
# Close_ETF    1.322778
# dtype: float64
# #####################
#  Standard deviation for sample number: 42
# Close_ETF    1.074292
# dtype: float64
# #####################
#  Standard deviation for sample number: 43
# Close_ETF    1.554283
# dtype: float64
# #####################
#  Standard deviation for sample number: 44
# Close_ETF    1.368322
# dtype: float64
# #####################
#  Standard deviation for sample number: 45
# Close_ETF    1.098144
# dtype: float64
# #####################
#  Standard deviation for sample number: 46
# Close_ETF    0.823119
# dtype: float64
# #####################
#  Standard deviation for sample number: 47
# Close_ETF    1.202266
# dtype: float64
# #####################
#  Standard deviation for sample number: 48
# Close_ETF    1.914112
# dtype: float64
# #####################
#  Standard deviation for sample number: 49
# Close_ETF    2.090152
# dtype: float64
# #####################
#  Standard deviation for sample number: 50
# Close_ETF    1.213737
# dtype: float64

# %%
sns.distplot(mean)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(stand)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Part-5

# %%
# Creating a population replace with your own: 
population = data.Close_ETF.tolist()

sampleSize=10
value=100

for x in range(sampleSize):
    # Creating a random sample of the population with size 50: 
    sample = random.sample(population,value)  # With Replacment means the sample can contain the duplicates of the original population.

# %%
arr1 = np.array(sample)
arr1
# Out:
# array([120.870003, 138.610001, 133.690002, 113.919998, 126.760002,
#        127.029999, 115.75    , 128.080002, 103.779999, 138.669998,
#        129.      , 103.360001, 124.089996, 144.660004, 115.019997,
#         99.300003, 112.849998, 147.270004, 131.869995, 119.480003,
#        118.599998, 143.690002, 102.449997, 111.449997, 123.089996,
#        121.75    , 130.690002, 142.130005, 109.75    , 130.279999,
#        119.370003, 114.389999, 109.709999, 118.440002, 130.949997,
#        148.119995,  99.620003, 117.239998, 123.910004, 113.650002,
#        136.860001, 119.779999, 103.68    , 116.160004, 125.410004,
#        110.029999, 117.5     , 122.650002, 137.910004, 100.110001,
#        123.739998, 127.129997, 131.009995, 119.120003, 120.760002,
#        129.270004, 116.900002, 147.229996, 127.440002, 136.589996,
#        106.400002, 121.43    , 150.75    , 150.860001, 109.620003,
#        112.879997, 112.800003, 120.480003, 114.5     , 133.580002,
#        141.289993, 116.330002, 126.809998, 128.229996, 137.470001,
#        108.139999, 141.190002, 143.179993, 115.870003, 113.220001,
#        148.289993, 108.900002, 115.989998, 118.440002, 127.75    ,
#        121.18    , 133.360001,  98.800003, 138.779999, 142.160004,
#        122.239998, 113.18    , 105.150002, 122.599998, 112.580002,
#        120.760002, 124.      , 114.389999, 123.339996, 113.970001])

# %%
import scipy.stats


def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return  m,m-h, m+h

# %% [markdown]
# Part-5 (2)
#
# 95% confidence interval for one of the10 simple random samples

# %%
mean_confidence_interval(sample, confidence=0.95)
# Out:
# (123.03510011, 120.48259368089836, 125.58760653910164)

# %%
# to get 50 simple random sample


sampleSize=50
value=20

for x in range(sampleSize):
    # Creating a random sample of the population with size 50: 
    sample2 = random.sample(population,value)

# %%
sample2
# Out:
# [119.779999,
#  121.220001,
#  133.580002,
#  119.209999,
#  102.449997,
#  115.019997,
#  131.009995,
#  129.270004,
#  127.970001,
#  119.410004,
#  114.199997,
#  129.539993,
#  111.730003,
#  114.389999,
#  118.57,
#  135.089996,
#  111.120003,
#  111.889999,
#  127.410004,
#  112.059998]

# %% [markdown]
# 95% confidence interval for one of the 50 simple random samples

# %%
mean_confidence_interval(sample2, confidence=0.95)
# Out:
# (120.24599955, 116.07921903958153, 124.41278006041846)

# %% [markdown]
# From part-1 we can see that the population mean is 121.152960. The confidence interval for one of the 10 simple random samples (118.55831271106874, 124.21068708893125) and for one of the 50 simple random samples (115.21115748491609, 126.00284151508392) . Hence, the two intervals from (1) and (2) include the true value of the population mean 𝝁 which is 121.152960 as it lies within the confidence interval.
# The 2nd case includes 50 simple random samples of the population, which is more than 10 simple random samples, and hence, a better representation of the populaion. So, it will be more accurate.
# Since the true value lies within the interval for both the samples, we can say that both are accuarate in this case.

# %% [markdown]
# Part-6
#
# (T-test)
# (1) & (2)

# %%
import scipy.stats as stats
stats.ttest_ind(data['Close_ETF'],sample)
# Out:
# Ttest_indResult(statistic=-4.357722498038532, pvalue=1.4375162902844965e-05)

# %%
stats.ttest_ind(data['Close_ETF'],sample2)
# Out:
# Ttest_indResult(statistic=0.48962029349504665, pvalue=0.6245082036346657)

# %% [markdown]
# (3) & (4)

# %%
stats.f_oneway(sample,sample2)
# Out:
# F_onewayResult(statistic=0.8552137876390556, pvalue=0.35696889362483386)

# %%
stats.f_oneway(sample,data['Close_ETF'])
# Out:
# F_onewayResult(statistic=18.989745369911063, pvalue=1.4375162902852163e-05)

# %%
stats.f_oneway(sample2,data['Close_ETF'])
# Out:
# F_onewayResult(statistic=0.23972803180217456, pvalue=0.6245082036347465)

# %% [markdown]
# part-8

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

data=data.iloc[:999]

# %%
X=np.array(data['gold'])
X = X.reshape(-1,1)
y=np.array(data['Close_ETF'])
y = y.reshape(-1,1)

# %%
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

# %%
model=LinearRegression()

scores = cross_val_score(model, X_train, y_train, cv= 5)
print(scores)
# Out:
# [-0.00437544 -0.00168867 -0.00453835 -0.00580707 -0.01108864]

# %%
model=model.fit(X_train, y_train)
y_pred=model.predict(X_test)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(data['gold'], data['Close_ETF'])
ax.set_xlabel('input - x')
ax.set_ylabel('target - y')
plt.show()

plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,model.predict(X_train),color='blue')

# %%
MSE = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean squared error: ', MSE)
print('R2 Score: ', r2)
# Out:
# Mean squared error:  12.593793774257808
# R2 Score:  0.0026999429619439796

# %% [markdown]
# Removing outliers from gold and ETF

# %%
sns.boxplot(x=data['Close_ETF'])
# Out:
# <AxesSubplot:xlabel='Close_ETF'>

# %%
sns.boxplot(x=data['gold'])
# Out:
# <AxesSubplot:xlabel='gold'>

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter
#  4.82770442e-01 5.66943545e-01 3.20216090e-02 9.00253930e-01
#  8.04317529e-01 2.21716658e-01 1.45279792e-01 5.58475467e-01
#  2.36093867e-01 7.87802395e-02 5.20619083e-02 1.31726457e+00
#  4.64962026e-02 3.47812371e-01 6.06969817e-01 6.52848563e-02
#  1.24169958e-01 1.00848250e+00 6.46431010e-01 4.69523668e-01
#  2.63671512e-01 7.84762824e-01 8.93523240e-01 2.63836902e-01
#  8.42473636e-01 9.68075697e-02 1.39155823e+00 8.14900230e-01
#  3.77471390e-01 6.77609354e-01 2.44131608e-01 1.15999852e+00
#  8.12046040e-01 1.61707621e-01 3.93764242e-01 6.66655222e-01
#  2.12949808e+00 8.08042908e-01 3.36070889e-01 3.51927688e-01
#  1.41694133e+00 6.07800165e-01 4.53309058e-01 1.15425604e-01]

# %%
data['gold'] = np.where(data['gold'] >.02, .001030,data['gold'])

data['gold'] = np.where(data['gold'] <-.015, .001030,data['gold'])


sns.boxplot(x=data['gold'])

fig2, ax = plt.subplots(figsize=(16,8))
ax.scatter(data['Close_ETF'], data['gold'])
ax.set_xlabel('Close_ETF')
ax.set_ylabel('Full-value gold')
plt.show()

# %%
data['Close_ETF'] = np.where(data['Close_ETF'] >129, 121.152960,data['Close_ETF'])

data['Close_ETF'] = np.where(data['Close_ETF'] <112, 121.152960,data['Close_ETF'])

# %%
data=data.iloc[:999]

X=np.array(data['gold'])
X = X.reshape(-1,1)
y=np.array(data['Close_ETF'])
y = y.reshape(-1,1)

X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

model=LinearRegression()

scores = cross_val_score(model, X_train, y_train, cv= 5)
print(scores)

model=model.fit(X_train, y_train)
y_pred=model.predict(X_test)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(data['gold'], data['Close_ETF'])
ax.set_xlabel('input - x')
ax.set_ylabel('target - y')
plt.show()

plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,model.predict(X_train),color='blue')
# Out:
# [-0.00437544 -0.00168867 -0.00453835 -0.00580707 -0.01108864]

# %%
MSE = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean squared error: ', MSE)
print('R2 Score: ', r2)
# Out:
# Mean squared error:  12.593793774257808
# R2 Score:  0.0026999429619439796

# %%
minvalueIndexLabel = data['Close_ETF'].idxmin()
  
minvalueIndexLabel
# Out:
# 233

# %% [markdown]
# Removing outliers from Close_ETF

# %%
data['Close_ETF'] = np.where(data['Close_ETF'] >129, 121.152960,data['Close_ETF'])

data['Close_ETF'] = np.where(data['Close_ETF'] <112, 121.152960,data['Close_ETF'])

# %% [markdown]
# part 8
# (7)

# %% [markdown]
# 99% confidence interval of the mean daily ETF return,

# %%
mean_confidence_interval(col1, confidence=0.99)
# Out:
# (121.152960012, 120.12712955132923, 122.17879047267076)

# %%
mean_confidence_interval(col2, confidence=0.99)
# Out:
# (0.0006628360819999999, -0.0002584729930030417, 0.0015841451570030416)

# %% [markdown]
# 99% prediction interval of the individual daily ETF return.

# %%
mean_confidence_interval(y_pred, confidence=0.99)
# Out:
# (120.64373840837953, array([120.63812073]), array([120.64935609]))

# %%
mean_confidence_interval(X_test, confidence=0.99)
# Out:
# (0.0013872294, array([0.00034262]), array([0.00243184]))
